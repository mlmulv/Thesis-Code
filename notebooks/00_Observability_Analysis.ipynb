# %%
import numpy as np
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..', 'src')))
import utils
import gramian_obs

# %%
x0 = np.asarray([7,15,15,4,20])
n_pert = 5
c = 0.1
x_max = np.asarray([11,100,175,10,50])
sim_hours = 60
dt = 1.0
t = np.arange(0, sim_hours*60+1, dt) #0 to 60 hours with minute-level resolution
uex_func = utils.gen_uex_func(uex_const=0.3)
PN_func = utils.gen_PN_func(PN_const=0.1)
D_func = utils.gen_D_func(D_const=0.30)
SI_func = utils.gen_SI_func(SI_const=1.8e-4)
threshold = 0.1
Gramian = gramian_obs.EmperialGramianMatrix(x0=x0,n_pert=n_pert,c=c,x_max=x_max,t=t,dt=dt,uex_func=uex_func,PN_func=PN_func,D_func=D_func,SI_func=SI_func,threshold=threshold, SI_est=None) 
W_O, eig_vals, eig_vectors = Gramian.gramian()

# %%
eig_vals / np.linalg.norm(eig_vals)
# Out:
# array([3.10608383e-07, 6.29305381e-04, 3.73980680e-03, 1.89701911e-01,
#        9.81834407e-01])
